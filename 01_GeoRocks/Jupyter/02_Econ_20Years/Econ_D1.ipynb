# %% [markdown]
# <font size="6"> Economic calculation with a simple example </font>

# %% [markdown]
# ## Dataset introduction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# load example simulation data
data = pd.read_excel('time_data.xlsx')

# %%
# check available collumns in the dataset
data.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'P16 : BHP (bar)',
#  'P16 : p 17 reservoir P (bar)',
#  'P16 : p 17 c 1 rate (Kmol/day)',
#  'P16 : p 15 reservoir P (bar)',
#  'P16 : p 15 c 1 rate (Kmol/day)',
#  'P16 : p 15 c 0 rate (Kmol/day)',
#  'P16 : p 13 reservoir P (bar)',
#  'P16 : p 13 c 1 rate (Kmol/day)',
#  'P16 : p 13 c 0 rate (Kmol/day)',
#  'P16 : p 12 c 0 rate (Kmol/day)',
#  'P16 : p 11 reservoir P (bar)',
#  'P16 : p 10 reservoir P (bar)',
#  'P16 : p 10 c 1 rate (Kmol/day)',
#  'P16 : p 10 c 0 rate (Kmol/day)',
#  'P16 : p 9 c 1 rate (Kmol/day)',
#  'P16 : p 8 reservoir P (bar)',
#  'P16 : p 8 c 1 rate (Kmol/day)',
#  'P16 : p 8 c 0 rate (Kmol/day)',
#  'P16 : p 7 reservoir P (bar)',
#  'P16 : p 7 c 1 rate (Kmol/day)',
#  'P16 : p 6 reservoir P (bar)',
#  'P16 : p 6 c 1 rate (Kmol/day)',
#  'P16 : p 5 c 0 rate (Kmol/day)',
#  'P16 : p 4 reservoir P (bar)',
#  'P16 : p 4 c 1 rate (Kmol/day)',
#  'P16 : p 4 c 0 rate (Kmol/day)',
#  'P16 : p 3 reservoir P (bar)',
#  'P16 : p 3 c 1 rate (Kmol/day)',
#  'P16 : p 3 c 0 rate (Kmol/day)',
#  'P16 : p 2 reservoir P (bar)',
#  'P16 : p 2 c 1 rate (Kmol/day)',
#  'P16 : p 2 c 0 rate (Kmol/day)',
#  'P16 : p 1 c 0 rate (Kmol/day)',
#  'P16 : p 0 c 0 rate (Kmol/day)',
#  'P16 : c 0 rate (Kmol/day)',
#  'P16 : energy (KJ/day)',
#  'P16 : steam rate (m3/day)',
#  'P16 : water rate (m3/day)',
#  'P15 : BHP (bar)',
#  'P15 : p 19 reservoir P (bar)',
#  'P15 : p 19 c 1 rate (Kmol/day)',
#  'P15 : p 19 c 0 rate (Kmol/day)',
#  'P15 : p 17 reservoir P (bar)',
#  'P15 : p 17 c 1 rate (Kmol/day)',
#  'P15 : p 17 c 0 rate (Kmol/day)',
#  'P15 : p 16 c 1 rate (Kmol/day)',
#  'P15 : p 16 c 0 rate (Kmol/day)',
#  'P15 : p 15 c 1 rate (Kmol/day)',
#  'P15 : p 15 c 0 rate (Kmol/day)',
#  'P15 : p 14 reservoir P (bar)',
#  'P15 : p 13 c 1 rate (Kmol/day)',
#  'P15 : p 13 c 0 rate (Kmol/day)',
#  'P15 : p 12 c 1 rate (Kmol/day)',
#  'P15 : p 11 reservoir P (bar)',
#  'P15 : p 11 c 1 rate (Kmol/day)',
#  'P15 : p 10 reservoir P (bar)',
#  'E02 : p 19 c 0 rate (Kmol/day)',
#  'E02 : p 18 reservoir P (bar)',
#  'P02 : p 13 c 0 rate (Kmol/day)',
#  'E02 : p 17 reservoir P (bar)',
#  'E06 : p 6 c 0 rate (Kmol/day)',
#  'E02 : p 17 c 1 rate (Kmol/day)',
#  'E01 : p 17 c 0 rate (Kmol/day)',
#  'P11 : p 10 c 1 rate (Kmol/day)',
#  'P16 : p 18 c 1 rate (Kmol/day)',
#  'E02 : p 16 reservoir P (bar)',
#  'E02 : p 14 c 1 rate (Kmol/day)',
#  'E02 : p 14 c 0 rate (Kmol/day)',
#  'E02 : p 19 reservoir P (bar)',
#  'E02 : p 12 c 1 rate (Kmol/day)',
#  'I01 : energy (KJ/day)',
#  'E02 : p 8 reservoir P (bar)',
#  'E05 : p 6 c 0 rate (Kmol/day)',
#  'E02 : p 6 c 1 rate (Kmol/day)',
#  'E02 : p 5 reservoir P (bar)',
#  'P12 : p 18 c 0 rate (Kmol/day)',
#  'E02 : p 9 reservoir P (bar)',
#  'E02 : p 5 c 1 rate (Kmol/day)',
#  'E02 : p 5 c 0 rate (Kmol/day)',
#  'P03 : energy (KJ/day)',
#  'I03 : p 7 c 0 rate (Kmol/day)',
#  'E02 : p 15 reservoir P (bar)',
#  'E02 : p 1 reservoir P (bar)',
#  'E06 : p 10 reservoir P (bar)',
#  'P12 : p 16 c 1 rate (Kmol/day)',
#  'E02 : energy (KJ/day)',
#  'E02 : p 2 c 1 rate (Kmol/day)',
#  'E02 : temperature (K)',
#  'E02 : water rate (m3/day)',
#  'E05 : p 12 c 1 rate (Kmol/day)',
#  'P11 : p 14 reservoir P (bar)',
#  'E01 : p 19 c 1 rate (Kmol/day)',
#  'time',
#  'E01 : p 18 c 0 rate (Kmol/day)',
#  'P16 : temperature (K)',
#  'E01 : p 17 reservoir P (bar)',
#  'E01 : p 11 c 0 rate (Kmol/day)',
#  'E04 : p 10 c 0 rate (Kmol/day)',
#  'P12 : p 5 c 0 rate (Kmol/day)',
#  'E01 : p 15 c 1 rate (Kmol/day)',
#  'E01 : p 14 c 1 rate (Kmol/day)',
#  'E01 : p 13 c 0 rate (Kmol/day)',
#  'I03 : p 8 c 0 rate (Kmol/day)',
#  'P12 : p 9 c 0 rate (Kmol/day)',
#  'E02 : p 6 reservoir P (bar)',
#  'E02 : p 13 c 1 rate (Kmol/day)',
#  'E05 : p 8 c 1 rate (Kmol/day)',
#  'E01 : p 12 c 0 rate (Kmol/day)',
#  'E03 : water rate (m3/day)',
#  'E01 : p 11 reservoir P (bar)',
#  'E01 : p 11 c 1 rate (Kmol/day)',
#  'E01 : p 9 c 1 rate (Kmol/day)',
#  'P15 : p 18 reservoir P (bar)',
#  'E02 : p 7 c 1 rate (Kmol/day)',
#  'E01 : p 9 c 0 rate (Kmol/day)',
#  'I03 : p 13 reservoir P (bar)',
#  'E02 : p 11 c 1 rate (Kmol/day)',
#  'E01 : p 8 c 0 rate (Kmol/day)',
#  'P01 : p 8 c 0 rate (Kmol/day)',
#  'I02 : temperature (K)',
#  'E01 : p 7 reservoir P (bar)',
#  'P02 : p 17 c 1 rate (Kmol/day)',
#  'P02 : c 1 rate (Kmol/day)',
#  'I03 : p 18 c 1 rate (Kmol/day)',
#  'E02 : p 0 reservoir P (bar)',
#  'P03 : p 0 reservoir P (bar)',
#  'E01 : p 2 c 0 rate (Kmol/day)',
#  'I02 : p 13 c 1 rate (Kmol/day)',
#  'E01 : p 4 reservoir P (bar)',
#  'E02 : p 8 c 0 rate (Kmol/day)',
#  'I02 : p 18 c 1 rate (Kmol/day)',
#  'E01 : p 3 c 0 rate (Kmol/day)',
#  'E01 : p 1 reservoir P (bar)',
#  'I03 : water rate (m3/day)',
#  'E05 : p 10 c 1 rate (Kmol/day)',
#  'I03 : p 13 c 0 rate (Kmol/day)',
#  'I01 : p 17 reservoir P (bar)',
#  'E01 : p 1 c 0 rate (Kmol/day)',
#  'E01 : p 8 c 1 rate (Kmol/day)',
#  'P16 : p 6 c 0 rate (Kmol/day)',
#  'P01 : p 5 c 1 rate (Kmol/day)',
#  'E04 : p 16 c 0 rate (Kmol/day)',
#  'P16 : p 11 c 0 rate (Kmol/day)',
#  'E01 : c 1 rate (Kmol/day)',
#  'I02 : BHP (bar)',
#  'E01 : c 0 rate (Kmol/day)',
#  'E01 : energy (KJ/day)',
#  'E05 : p 8 reservoir P (bar)',
#  'E06 : p 10 c 0 rate (Kmol/day)',
#  'P14 : p 0 c 1 rate (Kmol/day)',
#  'P03 : p 19 reservoir P (bar)',
#  'P03 : p 6 c 0 rate (Kmol/day)',
#  'P02 : p 10 c 1 rate (Kmol/day)',
#  'P03 : p 18 c 1 rate (Kmol/day)',
#  'P01 : p 4 c 1 rate (Kmol/day)',
#  'E06 : p 3 reservoir P (bar)',
#  'E01 : p 7 c 1 rate (Kmol/day)',
#  'P13 : BHP (bar)',
#  'P11 : p 15 reservoir P (bar)',
#  'P03 : p 17 c 0 rate (Kmol/day)',
#  'E01 : p 8 reservoir P (bar)',
#  'E01 : p 3 reservoir P (bar)',
#  'P03 : p 15 reservoir P (bar)',
#  'I01 : p 14 c 0 rate (Kmol/day)',
#  'P03 : p 15 c 0 rate (Kmol/day)',
#  'P03 : p 14 c 1 rate (Kmol/day)',
#  'P15 : p 1 reservoir P (bar)',
#  'P16 : p 12 c 1 rate (Kmol/day)',
#  'P03 : p 12 reservoir P (bar)',
#  'P03 : p 12 c 0 rate (Kmol/day)',
#  'E04 : p 1 reservoir P (bar)',
#  'P03 : p 10 reservoir P (bar)',
#  'P12 : p 10 reservoir P (bar)',
#  'P03 : p 10 c 0 rate (Kmol/day)',
#  'E06 : water rate (m3/day)',
#  'P13 : p 13 c 1 rate (Kmol/day)',
#  'P03 : p 8 reservoir P (bar)',
#  'P03 : p 8 c 1 rate (Kmol/day)',
#  'E03 : p 16 reservoir P (bar)',
#  'FIPS c 0 (kmol)',
#  'P13 : p 16 c 0 rate (Kmol/day)',
#  'P03 : p 7 reservoir P (bar)',
#  'I01 : p 3 c 0 rate (Kmol/day)',
#  'E01 : p 10 c 1 rate (Kmol/day)',
#  'P03 : p 6 reservoir P (bar)',
#  'I03 : p 16 reservoir P (bar)',
#  'E04 : p 7 reservoir P (bar)',
#  'E06 : p 18 c 0 rate (Kmol/day)',
#  'P03 : p 6 c 1 rate (Kmol/day)',
#  'E03 : p 3 reservoir P (bar)',
#  'P03 : p 5 reservoir P (bar)',
#  'P03 : p 5 c 1 rate (Kmol/day)',
#  'E04 : p 6 c 0 rate (Kmol/day)',
#  'E02 : p 7 c 0 rate (Kmol/day)',
#  'P03 : p 4 reservoir P (bar)',
#  'E02 : p 9 c 0 rate (Kmol/day)',
#  'P03 : p 3 c 1 rate (Kmol/day)',
#  'I02 : p 9 reservoir P (bar)',
#  'E01 : steam rate (m3/day)',
#  'P15 : p 10 c 0 rate (Kmol/day)',
#  'E03 : p 19 c 0 rate (Kmol/day)',
#  'P03 : p 3 c 0 rate (Kmol/day)',
#  'P02 : water rate (m3/day)',
#  'P03 : p 2 c 1 rate (Kmol/day)',
#  'P13 : p 10 c 0 rate (Kmol/day)',
#  'P03 : p 2 c 0 rate (Kmol/day)',
#  'E03 : p 12 c 0 rate (Kmol/day)',
#  'E03 : p 10 reservoir P (bar)',
#  'P03 : water rate (m3/day)',
#  'I03 : p 19 reservoir P (bar)',
#  'E05 : p 18 c 1 rate (Kmol/day)',
#  'E01 : BHP (bar)',
#  'P01 : p 17 c 0 rate (Kmol/day)',
#  'E03 : energy (KJ/day)',
#  'P03 : p 13 c 0 rate (Kmol/day)',
#  'E05 : c 1 rate (Kmol/day)',
#  'I03 : p 18 reservoir P (bar)',
#  'E02 : p 19 c 1 rate (Kmol/day)',
#  'I03 : p 17 c 0 rate (Kmol/day)',
#  'P13 : p 6 c 0 rate (Kmol/day)',
#  'E01 : p 5 reservoir P (bar)',
#  'E06 : p 14 c 0 rate (Kmol/day)',
#  'I03 : p 16 c 1 rate (Kmol/day)',
#  'I03 : p 16 c 0 rate (Kmol/day)',
#  'E02 : p 1 c 1 rate (Kmol/day)',
#  'I03 : BHP (bar)',
#  'I03 : p 14 reservoir P (bar)',
#  'P01 : p 17 reservoir P (bar)',
#  'I03 : p 13 c 1 rate (Kmol/day)',
#  'E04 : p 8 c 1 rate (Kmol/day)',
#  'P15 : p 14 c 1 rate (Kmol/day)',
#  'P15 : p 3 c 1 rate (Kmol/day)',
#  'E01 : p 0 reservoir P (bar)',
#  'P03 : p 10 c 1 rate (Kmol/day)',
#  'P15 : p 3 c 0 rate (Kmol/day)',
#  'I03 : p 12 reservoir P (bar)',
#  'P02 : p 6 reservoir P (bar)',
#  'P13 : p 16 reservoir P (bar)',
#  'E02 : p 12 c 0 rate (Kmol/day)',
#  'P16 : p 1 reservoir P (bar)',
#  'E01 : p 3 c 1 rate (Kmol/day)',
#  'E01 : p 15 reservoir P (bar)',
#  'I01 : p 4 c 0 rate (Kmol/day)',
#  'I03 : p 11 reservoir P (bar)',
#  'P13 : p 17 reservoir P (bar)',
#  'I03 : p 11 c 0 rate (Kmol/day)',
#  'P11 : p 16 reservoir P (bar)',
#  'I03 : p 10 reservoir P (bar)',
#  'I03 : p 2 c 0 rate (Kmol/day)',
#  'E06 : p 5 reservoir P (bar)',
#  'I03 : p 10 c 1 rate (Kmol/day)',
#  'I03 : p 8 reservoir P (bar)',
#  'I03 : p 8 c 1 rate (Kmol/day)',
#  'I03 : p 7 reservoir P (bar)',
#  'I03 : p 6 c 0 rate (Kmol/day)',
#  'P01 : p 10 reservoir P (bar)',
#  'I02 : p 8 reservoir P (bar)',
#  'P11 : p 3 c 1 rate (Kmol/day)',
#  'I03 : p 5 reservoir P (bar)',
#  'P11 : energy (KJ/day)',
#  'I03 : p 5 c 1 rate (Kmol/day)',
#  'P14 : p 12 c 1 rate (Kmol/day)',
#  'P03 : p 9 c 1 rate (Kmol/day)',
#  'I03 : p 5 c 0 rate (Kmol/day)',
#  'E01 : p 16 c 1 rate (Kmol/day)',
#  'P03 : p 16 c 1 rate (Kmol/day)',
#  'I03 : p 18 c 0 rate (Kmol/day)',
#  'E04 : p 12 c 0 rate (Kmol/day)',
#  'E01 : p 13 c 1 rate (Kmol/day)',
#  'I03 : p 4 reservoir P (bar)',
#  'E05 : p 13 c 0 rate (Kmol/day)',
#  'P03 : p 19 c 0 rate (Kmol/day)',
#  'P15 : p 8 c 0 rate (Kmol/day)',
#  'I03 : p 4 c 0 rate (Kmol/day)',
#  'I03 : p 3 c 1 rate (Kmol/day)',
#  'E02 : p 0 c 0 rate (Kmol/day)',
#  'P03 : p 13 reservoir P (bar)',
#  'P14 : p 11 reservoir P (bar)',
#  'P15 : p 6 reservoir P (bar)',
#  'E03 : temperature (K)',
#  'I03 : p 1 reservoir P (bar)',
#  'I01 : p 17 c 1 rate (Kmol/day)',
#  'P16 : p 12 reservoir P (bar)',
#  'I03 : p 0 c 1 rate (Kmol/day)',
#  'P14 : p 10 c 1 rate (Kmol/day)',
#  'I03 : p 0 c 0 rate (Kmol/day)',
#  'E02 : p 10 reservoir P (bar)',
#  'I03 : c 1 rate (Kmol/day)',
#  'P03 : p 4 c 1 rate (Kmol/day)',
#  'I01 : p 9 c 1 rate (Kmol/day)',
#  'E02 : p 10 c 0 rate (Kmol/day)',
#  'E01 : p 16 c 0 rate (Kmol/day)',
#  'I03 : c 0 rate (Kmol/day)',
#  'I03 : temperature (K)',
#  'E04 : p 11 c 0 rate (Kmol/day)',
#  'P12 : p 11 c 0 rate (Kmol/day)',
#  'I03 : steam rate (m3/day)',
#  'P01 : p 18 reservoir P (bar)',
#  'I03 : p 1 c 0 rate (Kmol/day)',
#  'P02 : p 19 reservoir P (bar)',
#  'P01 : p 12 c 0 rate (Kmol/day)',
#  'P16 : p 11 c 1 rate (Kmol/day)',
#  'I01 : p 9 reservoir P (bar)',
#  'P11 : p 1 reservoir P (bar)',
#  'P02 : p 19 c 0 rate (Kmol/day)',
#  'P02 : p 18 reservoir P (bar)',
#  'P02 : p 18 c 0 rate (Kmol/day)',
#  'P02 : p 17 reservoir P (bar)',
#  'P02 : p 2 reservoir P (bar)',
#  'P12 : p 9 reservoir P (bar)',
#  'P03 : p 4 c 0 rate (Kmol/day)',
#  'P03 : c 1 rate (Kmol/day)',
#  'P12 : p 0 c 0 rate (Kmol/day)',
#  'P03 : p 14 reservoir P (bar)',
#  'P02 : p 16 reservoir P (bar)',
#  'P01 : p 17 c 1 rate (Kmol/day)',
#  'P01 : p 16 reservoir P (bar)',
#  'P01 : p 15 c 0 rate (Kmol/day)',
#  'P12 : p 19 c 0 rate (Kmol/day)',
#  'E02 : p 16 c 0 rate (Kmol/day)',
#  'E03 : p 19 c 1 rate (Kmol/day)',
#  'I01 : p 13 c 0 rate (Kmol/day)',
#  'P14 : p 19 c 1 rate (Kmol/day)',
#  'P01 : p 13 c 1 rate (Kmol/day)',
#  'P13 : p 18 c 0 rate (Kmol/day)',
#  'P01 : p 13 c 0 rate (Kmol/day)',
#  'P02 : p 2 c 0 rate (Kmol/day)',
#  'E02 : p 18 c 0 rate (Kmol/day)',
#  'I03 : p 19 c 1 rate (Kmol/day)',
#  'P02 : p 8 c 1 rate (Kmol/day)',
#  'E01 : p 18 reservoir P (bar)',
#  'E01 : p 13 reservoir P (bar)',
#  'E06 : p 12 c 0 rate (Kmol/day)',
#  'P01 : p 12 c 1 rate (Kmol/day)',
#  'P02 : p 2 c 1 rate (Kmol/day)',
#  'E03 : p 17 reservoir P (bar)',
#  'E02 : p 2 reservoir P (bar)',
#  'P01 : p 9 c 0 rate (Kmol/day)',
#  'E03 : p 11 c 1 rate (Kmol/day)',
#  'I01 : temperature (K)',
#  'P13 : p 5 c 0 rate (Kmol/day)',
#  'E01 : p 19 c 0 rate (Kmol/day)',
#  'E02 : p 6 c 0 rate (Kmol/day)',
#  'I02 : p 13 reservoir P (bar)',
#  'E02 : p 15 c 1 rate (Kmol/day)',
#  'P14 : p 8 reservoir P (bar)',
#  'P14 : p 11 c 0 rate (Kmol/day)',
#  'E01 : temperature (K)',
#  'E02 : p 4 c 1 rate (Kmol/day)',
#  'E05 : BHP (bar)',
#  'P03 : p 11 reservoir P (bar)',
#  'E03 : p 12 reservoir P (bar)',
#  'E04 : p 9 reservoir P (bar)',
#  'I03 : p 14 c 1 rate (Kmol/day)',
#  'P01 : p 5 c 0 rate (Kmol/day)',
#  'E02 : p 11 c 0 rate (Kmol/day)',
#  'P02 : p 11 c 0 rate (Kmol/day)',
#  'E03 : p 18 reservoir P (bar)',
#  'P01 : p 3 c 1 rate (Kmol/day)',
#  'E01 : p 2 c 1 rate (Kmol/day)',
#  'P15 : p 1 c 0 rate (Kmol/day)',
#  'E01 : p 6 c 0 rate (Kmol/day)',
#  'I02 : p 11 c 1 rate (Kmol/day)',
#  'P01 : p 1 c 0 rate (Kmol/day)',
#  'I01 : p 8 reservoir P (bar)',
#  'P01 : p 0 c 1 rate (Kmol/day)',
#  'P01 : p 3 c 0 rate (Kmol/day)',
#  'I01 : p 15 reservoir P (bar)',
#  'P01 : p 1 reservoir P (bar)',
#  'P16 : c 1 rate (Kmol/day)',
#  'E06 : p 10 c 1 rate (Kmol/day)',
#  'P13 : energy (KJ/day)',
#  'P16 : p 16 c 0 rate (Kmol/day)',
#  'P03 : p 3 reservoir P (bar)',
#  'E01 : p 4 c 1 rate (Kmol/day)',
#  'I01 : p 13 reservoir P (bar)',
#  'I03 : p 17 c 1 rate (Kmol/day)',
#  'P01 : energy (KJ/day)',
#  'P14 : p 2 reservoir P (bar)',
#  'P01 : water rate (m3/day)',
#  'P01 : p 9 c 1 rate (Kmol/day)',
#  'I02 : p 5 reservoir P (bar)',
#  'P03 : p 1 reservoir P (bar)',
#  'P02 : p 11 reservoir P (bar)',
#  'E06 : p 13 reservoir P (bar)',
#  'P15 : p 0 c 0 rate (Kmol/day)',
#  'P02 : p 4 c 0 rate (Kmol/day)',
#  'P01 : steam rate (m3/day)',
#  'I01 : p 7 c 0 rate (Kmol/day)',
#  'P15 : p 7 c 0 rate (Kmol/day)',
#  'P03 : p 11 c 1 rate (Kmol/day)',
#  'I02 : c 0 rate (Kmol/day)',
#  'P14 : p 4 reservoir P (bar)',
#  'E04 : p 4 c 0 rate (Kmol/day)',
#  'P16 : p 9 c 0 rate (Kmol/day)',
#  'E02 : p 16 c 1 rate (Kmol/day)',
#  'P15 : p 14 c 0 rate (Kmol/day)',
#  'P13 : p 13 c 0 rate (Kmol/day)',
#  'I03 : p 1 c 1 rate (Kmol/day)',
#  'I01 : BHP (bar)',
#  'I01 : p 19 reservoir P (bar)',
#  'P01 : p 10 c 1 rate (Kmol/day)',
#  'E03 : p 11 reservoir P (bar)',
#  'I03 : p 19 c 0 rate (Kmol/day)',
#  'I01 : p 19 c 1 rate (Kmol/day)',
#  'P12 : p 17 c 0 rate (Kmol/day)',
#  'I02 : p 1 c 0 rate (Kmol/day)',
#  'P03 : p 9 c 0 rate (Kmol/day)',
#  'E06 : p 8 c 1 rate (Kmol/day)',
#  'P13 : p 4 c 1 rate (Kmol/day)',
#  'P14 : c 1 rate (Kmol/day)',
#  'I01 : p 19 c 0 rate (Kmol/day)',
#  'P03 : p 7 c 0 rate (Kmol/day)',
#  'P15 : p 18 c 1 rate (Kmol/day)',
#  'I02 : p 16 c 1 rate (Kmol/day)',
#  'P11 : p 14 c 1 rate (Kmol/day)',
#  'P02 : p 1 reservoir P (bar)',
#  'E01 : p 1 c 1 rate (Kmol/day)',
#  'P02 : p 9 c 1 rate (Kmol/day)',
#  'I02 : p 17 c 0 rate (Kmol/day)',
#  'E05 : p 5 reservoir P (bar)',
#  'I01 : p 2 c 1 rate (Kmol/day)',
#  'P01 : p 13 reservoir P (bar)',
#  'P11 : temperature (K)',
#  'P12 : p 1 c 0 rate (Kmol/day)',
#  'I01 : p 4 reservoir P (bar)',
#  'I01 : p 6 reservoir P (bar)',
#  'E02 : p 13 reservoir P (bar)',
#  'I02 : p 7 c 0 rate (Kmol/day)',
#  'E02 : p 0 c 1 rate (Kmol/day)',
#  'P16 : p 0 c 1 rate (Kmol/day)',
#  'P03 : p 2 reservoir P (bar)',
#  'P15 : p 12 reservoir P (bar)',
#  'P01 : temperature (K)',
#  'P15 : water rate (m3/day)',
#  'I02 : p 18 reservoir P (bar)',
#  'P12 : steam rate (m3/day)',
#  'I01 : p 11 reservoir P (bar)',
#  'I01 : p 4 c 1 rate (Kmol/day)',
#  'E02 : p 11 reservoir P (bar)',
#  'I01 : p 2 reservoir P (bar)',
#  'E02 : steam rate (m3/day)',
#  'P02 : p 16 c 0 rate (Kmol/day)',
#  'P13 : p 13 reservoir P (bar)',
#  'P01 : p 15 c 1 rate (Kmol/day)',
#  'P13 : steam rate (m3/day)',
#  'I01 : p 9 c 0 rate (Kmol/day)',
#  'P13 : p 4 reservoir P (bar)',
#  'I01 : p 5 reservoir P (bar)',
#  'I02 : p 0 c 1 rate (Kmol/day)',
#  'E03 : p 1 c 1 rate (Kmol/day)',
#  'P01 : p 11 c 0 rate (Kmol/day)',
#  'E03 : p 3 c 1 rate (Kmol/day)',
#  'P01 : p 6 c 1 rate (Kmol/day)',
#  'I03 : p 14 c 0 rate (Kmol/day)',
#  'I02 : p 1 reservoir P (bar)',
#  'P12 : p 18 reservoir P (bar)',
#  'E02 : p 2 c 0 rate (Kmol/day)',
#  'P11 : p 2 c 1 rate (Kmol/day)',
#  'I01 : p 14 reservoir P (bar)',
#  'E04 : p 10 reservoir P (bar)',
#  'P14 : water rate (m3/day)',
#  'P14 : p 3 c 1 rate (Kmol/day)',
#  'I02 : p 14 c 1 rate (Kmol/day)',
#  'P01 : p 3 reservoir P (bar)',
#  'P02 : p 1 c 1 rate (Kmol/day)',
#  'I02 : p 14 c 0 rate (Kmol/day)',
#  'I02 : p 13 c 0 rate (Kmol/day)',
#  'E06 : p 2 c 0 rate (Kmol/day)',
#  'I01 : p 2 c 0 rate (Kmol/day)',
#  'E05 : p 6 c 1 rate (Kmol/day)',
#  'E05 : c 0 rate (Kmol/day)',
#  'P01 : p 8 reservoir P (bar)',
#  'E06 : p 18 reservoir P (bar)',
#  'E03 : p 18 c 0 rate (Kmol/day)',
#  'P01 : p 2 reservoir P (bar)',
#  'I01 : c 0 rate (Kmol/day)',
#  'I02 : p 3 c 1 rate (Kmol/day)',
#  'P01 : c 0 rate (Kmol/day)',
#  'I01 : p 14 c 1 rate (Kmol/day)',
#  'I02 : p 6 reservoir P (bar)',
#  'I02 : p 10 c 0 rate (Kmol/day)',
#  'E02 : p 14 reservoir P (bar)',
#  'E04 : p 18 c 1 rate (Kmol/day)',
#  'P03 : p 14 c 0 rate (Kmol/day)',
#  'P03 : p 17 c 1 rate (Kmol/day)',
#  'E01 : p 10 reservoir P (bar)',
#  'P12 : p 19 reservoir P (bar)',
#  'I02 : p 15 reservoir P (bar)',
#  'P03 : p 9 reservoir P (bar)',
#  'P01 : p 1 c 1 rate (Kmol/day)',
#  'I02 : p 5 c 1 rate (Kmol/day)',
#  'P03 : p 7 c 1 rate (Kmol/day)',
#  'E06 : p 19 reservoir P (bar)',
#  'I01 : p 10 c 1 rate (Kmol/day)',
#  'I02 : p 4 reservoir P (bar)',
#  'E04 : p 17 reservoir P (bar)',
#  'I01 : p 5 c 1 rate (Kmol/day)',
#  'P12 : p 6 c 1 rate (Kmol/day)',
#  'I01 : p 16 c 1 rate (Kmol/day)',
#  'I01 : p 16 reservoir P (bar)',
#  'E02 : c 1 rate (Kmol/day)',
#  'E05 : p 1 c 0 rate (Kmol/day)',
#  'I01 : p 1 c 0 rate (Kmol/day)',
#  'I01 : p 0 c 0 rate (Kmol/day)',
#  'I01 : water rate (m3/day)',
#  'I01 : p 6 c 1 rate (Kmol/day)',
#  'P11 : p 13 reservoir P (bar)',
#  'P01 : p 14 reservoir P (bar)',
#  'I03 : p 11 c 1 rate (Kmol/day)',
#  'E04 : p 16 reservoir P (bar)',
#  'I03 : p 6 c 1 rate (Kmol/day)',
#  'E01 : water rate (m3/day)',
#  'E04 : c 0 rate (Kmol/day)',
#  'I01 : p 3 reservoir P (bar)',
#  'I01 : p 15 c 1 rate (Kmol/day)',
#  'E02 : p 3 reservoir P (bar)',
#  'P13 : p 8 reservoir P (bar)',
#  'P01 : p 10 c 0 rate (Kmol/day)',
#  'E06 : p 15 reservoir P (bar)',
#  'P11 : p 10 reservoir P (bar)',
#  'P03 : BHP (bar)',
#  'I01 : p 7 reservoir P (bar)',
#  'P02 : p 3 reservoir P (bar)',
#  'I02 : p 9 c 1 rate (Kmol/day)',
#  'E05 : p 11 c 1 rate (Kmol/day)',
#  'P16 : p 1 c 1 rate (Kmol/day)',
#  'E01 : p 10 c 0 rate (Kmol/day)',
#  'I03 : p 15 reservoir P (bar)',
#  'E01 : p 0 c 0 rate (Kmol/day)',
#  'I03 : p 6 reservoir P (bar)',
#  'P11 : p 5 c 0 rate (Kmol/day)',
#  'E03 : p 8 reservoir P (bar)',
#  'P03 : p 19 c 1 rate (Kmol/day)',
#  'I01 : p 10 c 0 rate (Kmol/day)',
#  'E03 : p 6 c 0 rate (Kmol/day)',
#  'I02 : p 16 reservoir P (bar)',
#  'E04 : p 16 c 1 rate (Kmol/day)',
#  'P01 : c 1 rate (Kmol/day)',
#  'P02 : p 14 reservoir P (bar)',
#  'I01 : p 0 c 1 rate (Kmol/day)',
#  'P02 : p 19 c 1 rate (Kmol/day)',
#  'I01 : p 10 reservoir P (bar)',
#  'P01 : p 8 c 1 rate (Kmol/day)',
#  'P13 : p 12 c 0 rate (Kmol/day)',
#  'P01 : p 16 c 1 rate (Kmol/day)',
#  'I01 : p 8 c 1 rate (Kmol/day)',
#  'E03 : p 15 c 1 rate (Kmol/day)',
#  'I01 : p 11 c 0 rate (Kmol/day)',
#  'I01 : p 6 c 0 rate (Kmol/day)',
#  'P01 : p 6 c 0 rate (Kmol/day)',
#  'E04 : p 5 c 1 rate (Kmol/day)',
#  'E02 : c 0 rate (Kmol/day)',
#  'E06 : p 0 c 0 rate (Kmol/day)',
#  'E02 : p 10 c 1 rate (Kmol/day)',
#  'E05 : p 1 c 1 rate (Kmol/day)',
#  'E04 : p 11 reservoir P (bar)',
#  'P01 : p 5 reservoir P (bar)',
#  'E02 : p 1 c 0 rate (Kmol/day)',
#  'P12 : p 8 reservoir P (bar)',
#  'I01 : p 18 c 1 rate (Kmol/day)',
#  'P03 : steam rate (m3/day)',
#  'P14 : c 0 rate (Kmol/day)',
#  'I02 : steam rate (m3/day)',
#  'E06 : p 8 reservoir P (bar)',
#  'E02 : BHP (bar)',
#  'I01 : p 7 c 1 rate (Kmol/day)',
#  'I02 : p 10 c 1 rate (Kmol/day)',
#  'E03 : p 10 c 0 rate (Kmol/day)',
#  'E04 : p 12 reservoir P (bar)',
#  'P12 : p 17 c 1 rate (Kmol/day)',
#  'P15 : p 10 c 1 rate (Kmol/day)',
#  'I01 : p 12 c 0 rate (Kmol/day)',
#  'P15 : p 13 reservoir P (bar)',
#  'I01 : p 13 c 1 rate (Kmol/day)',
#  'P01 : p 11 reservoir P (bar)',
#  'I01 : p 1 reservoir P (bar)',
#  'I01 : p 12 c 1 rate (Kmol/day)',
#  'P14 : p 18 c 0 rate (Kmol/day)',
#  'P13 : c 0 rate (Kmol/day)',
#  'P01 : p 2 c 1 rate (Kmol/day)',
#  'P12 : p 8 c 0 rate (Kmol/day)',
#  'I01 : p 8 c 0 rate (Kmol/day)',
#  'P02 : p 10 reservoir P (bar)',
#  'P13 : p 11 c 0 rate (Kmol/day)',
#  'P01 : p 18 c 0 rate (Kmol/day)',
#  'P03 : p 0 c 0 rate (Kmol/day)',
#  'E04 : p 0 reservoir P (bar)',
#  'P11 : p 5 c 1 rate (Kmol/day)',
#  'P01 : p 18 c 1 rate (Kmol/day)',
#  'P15 : p 15 reservoir P (bar)',
#  'P11 : p 9 c 0 rate (Kmol/day)',
#  'P14 : p 5 c 0 rate (Kmol/day)',
#  'I01 : p 11 c 1 rate (Kmol/day)',
#  'P03 : c 0 rate (Kmol/day)',
#  'E02 : p 17 c 0 rate (Kmol/day)',
#  'E03 : p 2 c 0 rate (Kmol/day)',
#  'E04 : p 12 c 1 rate (Kmol/day)',
#  'I02 : p 10 reservoir P (bar)',
#  'P02 : p 14 c 0 rate (Kmol/day)',
#  'E04 : p 13 c 0 rate (Kmol/day)',
#  'P01 : p 19 c 0 rate (Kmol/day)',
#  'E03 : p 16 c 1 rate (Kmol/day)',
#  'I03 : p 12 c 0 rate (Kmol/day)',
#  'I02 : p 0 reservoir P (bar)',
#  'I02 : p 4 c 1 rate (Kmol/day)',
#  'P01 : p 19 c 1 rate (Kmol/day)',
#  'P03 : p 18 reservoir P (bar)',
#  'I03 : p 2 reservoir P (bar)',
#  'P01 : p 9 reservoir P (bar)',
#  'P14 : p 10 reservoir P (bar)',
#  'I02 : p 1 c 1 rate (Kmol/day)',
#  'P02 : p 12 reservoir P (bar)',
#  'P11 : p 4 c 0 rate (Kmol/day)',
#  'E01 : p 9 reservoir P (bar)',
#  'P03 : p 16 c 0 rate (Kmol/day)',
#  'E02 : p 12 reservoir P (bar)',
#  'P02 : temperature (K)',
#  'P14 : p 6 reservoir P (bar)',
#  'I03 : p 15 c 1 rate (Kmol/day)',
#  'I02 : p 14 reservoir P (bar)',
#  'P14 : p 9 reservoir P (bar)',
#  'P01 : p 7 c 0 rate (Kmol/day)',
#  'I03 : p 9 c 1 rate (Kmol/day)',
#  'E03 : p 3 c 0 rate (Kmol/day)',
#  'E01 : p 12 reservoir P (bar)',
#  'P02 : p 7 c 1 rate (Kmol/day)',
#  'P03 : p 17 reservoir P (bar)',
#  'P02 : BHP (bar)',
#  'E01 : p 12 c 1 rate (Kmol/day)',
#  'I02 : p 2 c 0 rate (Kmol/day)',
#  'I02 : p 2 c 1 rate (Kmol/day)',
#  'P02 : p 16 c 1 rate (Kmol/day)',
#  'P03 : p 18 c 0 rate (Kmol/day)',
#  'I02 : p 4 c 0 rate (Kmol/day)',
#  'P03 : p 16 reservoir P (bar)',
#  'P01 : p 15 reservoir P (bar)',
#  'I02 : p 16 c 0 rate (Kmol/day)',
#  'I02 : p 12 c 0 rate (Kmol/day)',
#  'E03 : p 0 reservoir P (bar)',
#  'I02 : p 5 c 0 rate (Kmol/day)',
#  'E02 : p 15 c 0 rate (Kmol/day)',
#  'P03 : p 0 c 1 rate (Kmol/day)',
#  'P11 : p 17 c 0 rate (Kmol/day)',
#  'I02 : p 6 c 0 rate (Kmol/day)',
#  'I01 : p 15 c 0 rate (Kmol/day)',
#  'I02 : p 6 c 1 rate (Kmol/day)',
#  'P16 : p 17 c 0 rate (Kmol/day)',
#  'E06 : p 5 c 0 rate (Kmol/day)',
#  'P13 : temperature (K)',
#  'P15 : p 18 c 0 rate (Kmol/day)',
#  'P02 : p 0 c 1 rate (Kmol/day)',
#  'P03 : temperature (K)',
#  'I02 : p 7 reservoir P (bar)',
#  'P13 : p 11 c 1 rate (Kmol/day)',
#  'I02 : p 8 c 0 rate (Kmol/day)',
#  'I02 : p 18 c 0 rate (Kmol/day)',
#  'E01 : p 15 c 0 rate (Kmol/day)',
#  'I02 : p 9 c 0 rate (Kmol/day)',
#  'E02 : p 18 c 1 rate (Kmol/day)',
#  'E04 : p 2 reservoir P (bar)',
#  'I02 : p 11 c 0 rate (Kmol/day)',
#  'P15 : p 11 c 0 rate (Kmol/day)',
#  'P02 : p 8 c 0 rate (Kmol/day)',
#  'P02 : p 14 c 1 rate (Kmol/day)',
#  'E03 : p 0 c 1 rate (Kmol/day)',
#  'E05 : p 0 reservoir P (bar)',
#  'I02 : p 11 reservoir P (bar)',
#  'P16 : p 14 c 0 rate (Kmol/day)',
#  'P12 : p 16 reservoir P (bar)',
#  'I01 : p 18 reservoir P (bar)',
#  'P11 : p 11 c 0 rate (Kmol/day)',
#  'E01 : p 6 reservoir P (bar)',
#  'I02 : p 12 reservoir P (bar)',
#  'E06 : p 15 c 0 rate (Kmol/day)',
#  'P14 : temperature (K)',
#  'P14 : p 2 c 1 rate (Kmol/day)',
#  'P01 : p 19 reservoir P (bar)',
#  'I02 : p 17 c 1 rate (Kmol/day)',
#  'I02 : p 17 reservoir P (bar)',
#  'I01 : p 16 c 0 rate (Kmol/day)',
#  'P12 : p 15 c 1 rate (Kmol/day)',
#  'P13 : p 9 c 1 rate (Kmol/day)',
#  'I02 : p 19 c 0 rate (Kmol/day)',
#  'P02 : p 5 c 0 rate (Kmol/day)',
#  'E01 : p 17 c 1 rate (Kmol/day)',
#  'I03 : p 12 c 1 rate (Kmol/day)',
#  'P01 : p 0 c 0 rate (Kmol/day)',
#  'P12 : p 0 c 1 rate (Kmol/day)',
#  'I02 : p 19 reservoir P (bar)',
#  'P15 : p 9 c 1 rate (Kmol/day)',
#  'E01 : p 2 reservoir P (bar)',
#  'P12 : p 10 c 1 rate (Kmol/day)',
#  'P02 : p 6 c 0 rate (Kmol/day)',
#  'P01 : p 11 c 1 rate (Kmol/day)',
#  'P12 : p 4 reservoir P (bar)',
#  'P13 : p 8 c 0 rate (Kmol/day)',
#  'P15 : steam rate (m3/day)',
#  'P02 : p 1 c 0 rate (Kmol/day)',
#  'P02 : p 7 c 0 rate (Kmol/day)',
#  'P12 : p 3 c 1 rate (Kmol/day)',
#  'P02 : energy (KJ/day)',
#  'P02 : c 0 rate (Kmol/day)',
#  'P02 : p 9 reservoir P (bar)',
#  'P15 : p 5 c 1 rate (Kmol/day)',
#  'P16 : p 16 reservoir P (bar)',
#  'E02 : p 3 c 1 rate (Kmol/day)',
#  'I02 : c 1 rate (Kmol/day)',
#  'P02 : p 0 reservoir P (bar)',
#  'E03 : p 12 c 1 rate (Kmol/day)',
#  'P12 : p 6 c 0 rate (Kmol/day)',
#  'I02 : p 8 c 1 rate (Kmol/day)',
#  'P02 : p 12 c 0 rate (Kmol/day)',
#  'P12 : energy (KJ/day)',
#  'I03 : energy (KJ/day)',
#  'P02 : p 3 c 1 rate (Kmol/day)',
#  'P12 : p 12 c 1 rate (Kmol/day)',
#  'I01 : p 1 c 1 rate (Kmol/day)',
#  'E06 : p 9 c 1 rate (Kmol/day)',
#  'P02 : p 4 reservoir P (bar)',
#  'P11 : p 4 reservoir P (bar)',
#  'P13 : p 3 c 0 rate (Kmol/day)',
#  'E01 : p 16 reservoir P (bar)',
#  'P03 : p 8 c 0 rate (Kmol/day)',
#  'I01 : p 12 reservoir P (bar)',
#  'P13 : p 14 c 0 rate (Kmol/day)',
#  'P02 : p 5 c 1 rate (Kmol/day)',
#  'E05 : p 13 c 1 rate (Kmol/day)',
#  'E02 : p 3 c 0 rate (Kmol/day)',
#  'P02 : p 4 c 1 rate (Kmol/day)',
#  'P02 : p 5 reservoir P (bar)',
#  'E05 : p 3 c 0 rate (Kmol/day)',
#  'P16 : p 7 c 0 rate (Kmol/day)',
#  'E04 : p 5 reservoir P (bar)',
#  'P02 : p 3 c 0 rate (Kmol/day)',
#  'P11 : p 15 c 1 rate (Kmol/day)',
#  'P02 : p 6 c 1 rate (Kmol/day)',
#  'P11 : water rate (m3/day)',
#  'P02 : p 7 reservoir P (bar)',
#  'P02 : p 8 reservoir P (bar)',
#  'E05 : p 10 reservoir P (bar)',
#  'P13 : p 11 reservoir P (bar)',
#  'P15 : p 6 c 1 rate (Kmol/day)',
#  'P02 : p 9 c 0 rate (Kmol/day)',
#  'E01 : p 19 reservoir P (bar)',
#  'E01 : p 7 c 0 rate (Kmol/day)',
#  'I03 : p 7 c 1 rate (Kmol/day)',
#  'P02 : p 11 c 1 rate (Kmol/day)',
#  'P01 : p 2 c 0 rate (Kmol/day)',
#  'I02 : p 0 c 0 rate (Kmol/day)',
#  'E04 : p 9 c 1 rate (Kmol/day)',
#  'P01 : p 4 c 0 rate (Kmol/day)',
#  'P02 : p 10 c 0 rate (Kmol/day)',
#  'P03 : p 12 c 1 rate (Kmol/day)',
#  'E06 : p 14 reservoir P (bar)',
#  'I01 : p 3 c 1 rate (Kmol/day)',
#  'I03 : p 3 c 0 rate (Kmol/day)',
#  'E05 : p 14 reservoir P (bar)',
#  'P02 : p 13 c 1 rate (Kmol/day)',
#  'E05 : p 11 c 0 rate (Kmol/day)',
#  'P02 : p 12 c 1 rate (Kmol/day)',
#  'I01 : p 0 reservoir P (bar)',
#  'P11 : p 8 c 0 rate (Kmol/day)',
#  'I02 : p 7 c 1 rate (Kmol/day)',
#  'I01 : p 5 c 0 rate (Kmol/day)',
#  'P12 : p 9 c 1 rate (Kmol/day)',
#  'E04 : p 6 reservoir P (bar)',
#  'I01 : c 1 rate (Kmol/day)',
#  'P02 : p 13 reservoir P (bar)',
#  'P02 : p 15 reservoir P (bar)',
#  'P02 : p 17 c 0 rate (Kmol/day)',
#  'E03 : c 0 rate (Kmol/day)',
#  'E03 : c 1 rate (Kmol/day)',
#  'E03 : p 0 c 0 rate (Kmol/day)',
#  'P12 : p 13 reservoir P (bar)',
#  'E02 : p 4 reservoir P (bar)',
#  'E03 : p 1 c 0 rate (Kmol/day)',
#  'P12 : p 3 reservoir P (bar)',
#  'E03 : p 1 reservoir P (bar)',
#  'E03 : p 13 c 0 rate (Kmol/day)',
#  'I03 : p 0 reservoir P (bar)',
#  'E03 : p 4 c 0 rate (Kmol/day)',
#  'E03 : p 4 c 1 rate (Kmol/day)',
#  'E03 : p 4 reservoir P (bar)',
#  'E03 : p 5 c 0 rate (Kmol/day)',
#  'P12 : p 12 c 0 rate (Kmol/day)',
#  'P14 : p 18 reservoir P (bar)',
#  'E03 : p 5 c 1 rate (Kmol/day)',
#  'P14 : p 2 c 0 rate (Kmol/day)',
#  'E03 : p 5 reservoir P (bar)',
#  'E06 : p 1 c 1 rate (Kmol/day)',
#  'E03 : p 6 c 1 rate (Kmol/day)',
#  'E03 : p 6 reservoir P (bar)',
#  'P12 : p 0 reservoir P (bar)',
#  'E03 : p 7 c 1 rate (Kmol/day)',
#  'P12 : p 3 c 0 rate (Kmol/day)',
#  'E03 : p 7 reservoir P (bar)',
#  'E03 : p 8 c 0 rate (Kmol/day)',
#  'E06 : p 2 c 1 rate (Kmol/day)',
#  'E03 : p 8 c 1 rate (Kmol/day)',
#  'E03 : p 9 c 0 rate (Kmol/day)',
#  'E03 : p 9 c 1 rate (Kmol/day)',
#  'P12 : p 5 reservoir P (bar)',
#  'E03 : p 7 c 0 rate (Kmol/day)',
#  'E03 : p 10 c 1 rate (Kmol/day)',
#  'E03 : p 11 c 0 rate (Kmol/day)',
#  'P12 : p 19 c 1 rate (Kmol/day)',
#  'E03 : p 13 c 1 rate (Kmol/day)',
#  'E02 : p 4 c 0 rate (Kmol/day)',
#  'E03 : p 13 reservoir P (bar)',
#  'P02 : p 15 c 1 rate (Kmol/day)',
#  'E03 : p 14 c 0 rate (Kmol/day)',
#  'P01 : p 16 c 0 rate (Kmol/day)',
#  'P14 : p 5 c 1 rate (Kmol/day)',
#  'P12 : p 11 reservoir P (bar)',
#  'E03 : p 14 reservoir P (bar)',
#  'E03 : p 15 c 0 rate (Kmol/day)',
#  'E03 : p 15 reservoir P (bar)',
#  'E03 : p 16 c 0 rate (Kmol/day)',
#  'E03 : p 17 c 0 rate (Kmol/day)',
#  'E03 : p 17 c 1 rate (Kmol/day)',
#  'P01 : p 7 reservoir P (bar)',
#  'E03 : p 18 c 1 rate (Kmol/day)',
#  'P14 : p 16 c 0 rate (Kmol/day)',
#  'E03 : p 19 reservoir P (bar)',
#  'E03 : BHP (bar)',
#  'E04 : water rate (m3/day)',
#  'E04 : p 15 c 1 rate (Kmol/day)',
#  'E04 : steam rate (m3/day)',
#  'E04 : temperature (K)',
#  'E04 : energy (KJ/day)',
#  'E04 : c 1 rate (Kmol/day)',
#  'E04 : p 0 c 0 rate (Kmol/day)',
#  'P03 : p 1 c 1 rate (Kmol/day)',
#  'P14 : p 11 c 1 rate (Kmol/day)',
#  'E04 : p 0 c 1 rate (Kmol/day)',
#  'E01 : p 5 c 0 rate (Kmol/day)',
#  'P14 : p 6 c 1 rate (Kmol/day)',
#  'P14 : p 17 reservoir P (bar)',
#  'P02 : p 15 c 0 rate (Kmol/day)',
#  'E04 : p 1 c 0 rate (Kmol/day)',
#  'P11 : p 6 c 1 rate (Kmol/day)',
#  'E04 : p 1 c 1 rate (Kmol/day)',
#  'P15 : p 7 c 1 rate (Kmol/day)',
#  'E04 : p 2 c 0 rate (Kmol/day)',
#  'E05 : p 2 c 0 rate (Kmol/day)',
#  'P15 : p 12 c 0 rate (Kmol/day)',
#  'E04 : p 2 c 1 rate (Kmol/day)',
#  'P02 : steam rate (m3/day)',
#  'P14 : p 16 reservoir P (bar)',
#  'I02 : p 3 c 0 rate (Kmol/day)',
#  'E04 : p 3 c 1 rate (Kmol/day)',
#  'E04 : p 3 reservoir P (bar)',
#  'E04 : p 4 c 1 rate (Kmol/day)',
#  'E04 : p 4 reservoir P (bar)',
#  'E04 : p 5 c 0 rate (Kmol/day)',
#  'E05 : p 16 reservoir P (bar)',
#  'E04 : p 7 c 0 rate (Kmol/day)',
#  'E04 : p 8 c 0 rate (Kmol/day)',
#  'P01 : p 7 c 1 rate (Kmol/day)',
#  'E05 : p 7 reservoir P (bar)',
#  'P01 : p 4 reservoir P (bar)',
#  'E04 : p 8 reservoir P (bar)',
#  'E04 : p 9 c 0 rate (Kmol/day)',
#  'E04 : p 10 c 1 rate (Kmol/day)',
#  'E04 : p 7 c 1 rate (Kmol/day)',
#  'E04 : p 11 c 1 rate (Kmol/day)',
#  'E05 : p 14 c 0 rate (Kmol/day)',
#  'E04 : p 13 c 1 rate (Kmol/day)',
#  'E04 : p 13 reservoir P (bar)',
#  'E04 : p 14 c 1 rate (Kmol/day)',
#  'E04 : p 14 c 0 rate (Kmol/day)',
#  'P13 : p 10 c 1 rate (Kmol/day)',
#  'I03 : p 9 c 0 rate (Kmol/day)',
#  'E04 : p 14 reservoir P (bar)',
#  'E01 : p 18 c 1 rate (Kmol/day)',
#  'E04 : p 15 c 0 rate (Kmol/day)',
#  'E06 : p 17 c 1 rate (Kmol/day)',
#  'P11 : p 17 reservoir P (bar)',
#  'E04 : p 15 reservoir P (bar)',
#  'E04 : p 17 c 0 rate (Kmol/day)',
#  'E04 : p 17 c 1 rate (Kmol/day)',
#  'E04 : p 18 c 0 rate (Kmol/day)',
#  'P15 : p 1 c 1 rate (Kmol/day)',
#  'E04 : p 18 reservoir P (bar)',
#  'I02 : energy (KJ/day)',
#  'E04 : p 19 c 0 rate (Kmol/day)',
#  'P11 : p 16 c 0 rate (Kmol/day)',
#  'P01 : p 14 c 0 rate (Kmol/day)',
#  'E04 : p 19 c 1 rate (Kmol/day)',
#  'E04 : p 19 reservoir P (bar)',
#  'I01 : steam rate (m3/day)',
#  'P12 : p 15 c 0 rate (Kmol/day)',
#  'E04 : BHP (bar)',
#  'E05 : water rate (m3/day)',
#  'E06 : p 11 reservoir P (bar)',
#  'E05 : steam rate (m3/day)',
#  'E05 : temperature (K)',
#  'E05 : energy (KJ/day)',
#  'P16 : p 18 reservoir P (bar)',
#  'P03 : p 15 c 1 rate (Kmol/day)',
#  'P02 : p 18 c 1 rate (Kmol/day)',
#  'E05 : p 0 c 1 rate (Kmol/day)',
#  'P01 : BHP (bar)',
#  'E05 : p 1 reservoir P (bar)',
#  'E02 : p 7 reservoir P (bar)',
#  'P11 : p 13 c 1 rate (Kmol/day)',
#  'E05 : p 2 c 1 rate (Kmol/day)',
#  'E05 : p 2 reservoir P (bar)',
#  'P13 : p 1 c 1 rate (Kmol/day)',
#  'E05 : p 3 c 1 rate (Kmol/day)',
#  'E06 : p 7 reservoir P (bar)',
#  'E05 : p 3 reservoir P (bar)',
#  'P12 : p 8 c 1 rate (Kmol/day)',
#  'E05 : p 4 c 1 rate (Kmol/day)',
#  'P01 : p 14 c 1 rate (Kmol/day)',
#  'P15 : p 2 c 1 rate (Kmol/day)',
#  'E05 : p 4 reservoir P (bar)',
#  'E05 : p 5 c 0 rate (Kmol/day)',
#  'E05 : p 5 c 1 rate (Kmol/day)',
#  'E05 : p 6 reservoir P (bar)',
#  'E05 : p 7 c 0 rate (Kmol/day)',
#  'E05 : p 7 c 1 rate (Kmol/day)',
#  'P12 : temperature (K)',
#  'P12 : p 6 reservoir P (bar)',
#  'P15 : p 0 c 1 rate (Kmol/day)',
#  'E05 : p 8 c 0 rate (Kmol/day)',
#  'P11 : p 9 reservoir P (bar)',
#  'P01 : p 6 reservoir P (bar)',
#  'P13 : p 2 c 0 rate (Kmol/day)',
#  'E05 : p 9 c 0 rate (Kmol/day)',
#  'E05 : p 9 c 1 rate (Kmol/day)',
#  'E06 : p 4 c 0 rate (Kmol/day)',
#  'E05 : p 9 reservoir P (bar)',
#  'P14 : p 14 c 0 rate (Kmol/day)',
#  'E05 : p 10 c 0 rate (Kmol/day)',
#  'E05 : p 11 reservoir P (bar)',
#  'I03 : p 2 c 1 rate (Kmol/day)',
#  'E05 : p 12 c 0 rate (Kmol/day)',
#  'P14 : p 19 c 0 rate (Kmol/day)',
#  'E05 : p 12 reservoir P (bar)',
#  'I02 : p 15 c 1 rate (Kmol/day)',
#  'E05 : p 13 reservoir P (bar)',
#  'P14 : p 13 c 0 rate (Kmol/day)',
#  'P12 : p 1 c 1 rate (Kmol/day)',
#  'E05 : p 15 c 1 rate (Kmol/day)',
#  'E06 : p 13 c 1 rate (Kmol/day)',
#  'E05 : p 16 c 0 rate (Kmol/day)',
#  'E05 : p 17 c 0 rate (Kmol/day)',
#  'E05 : p 17 reservoir P (bar)',
#  'P15 : p 8 c 1 rate (Kmol/day)',
#  'E05 : p 18 c 0 rate (Kmol/day)',
#  'E05 : p 18 reservoir P (bar)',
#  'E05 : p 17 c 1 rate (Kmol/day)',
#  'E05 : p 19 c 0 rate (Kmol/day)',
#  'I03 : p 17 reservoir P (bar)',
#  'P11 : p 11 reservoir P (bar)',
#  'E05 : p 19 c 1 rate (Kmol/day)',
#  'E05 : p 19 reservoir P (bar)',
#  'E06 : steam rate (m3/day)',
#  'P16 : p 19 c 1 rate (Kmol/day)',
#  'P13 : p 19 c 1 rate (Kmol/day)',
#  'E06 : p 1 c 0 rate (Kmol/day)',
#  'E06 : energy (KJ/day)',
#  'E06 : c 0 rate (Kmol/day)',
#  'E06 : c 1 rate (Kmol/day)',
#  'E06 : p 0 c 1 rate (Kmol/day)',
#  'E06 : p 0 reservoir P (bar)',
#  'P14 : p 0 c 0 rate (Kmol/day)',
#  'E06 : p 1 reservoir P (bar)',
#  'E06 : p 2 reservoir P (bar)',
#  'E01 : p 0 c 1 rate (Kmol/day)',
#  'E06 : temperature (K)',
#  'P14 : p 15 c 0 rate (Kmol/day)',
#  'P14 : steam rate (m3/day)',
#  'E06 : p 3 c 0 rate (Kmol/day)',
#  'P14 : p 15 reservoir P (bar)',
#  'E06 : p 3 c 1 rate (Kmol/day)',
#  'E06 : p 4 c 1 rate (Kmol/day)',
#  'E06 : p 4 reservoir P (bar)',
#  'P11 : p 9 c 1 rate (Kmol/day)',
#  'P13 : p 14 reservoir P (bar)',
#  'E06 : p 5 c 1 rate (Kmol/day)',
#  'P12 : p 13 c 1 rate (Kmol/day)',
#  'E06 : p 6 c 1 rate (Kmol/day)',
#  'E06 : p 6 reservoir P (bar)',
#  'E06 : p 7 c 0 rate (Kmol/day)',
#  'P16 : p 0 reservoir P (bar)',
#  'E04 : p 3 c 0 rate (Kmol/day)',
#  'E06 : p 7 c 1 rate (Kmol/day)',
#  'E06 : p 8 c 0 rate (Kmol/day)',
#  'E06 : p 9 c 0 rate (Kmol/day)',
#  'E06 : p 9 reservoir P (bar)',
#  'P12 : p 11 c 1 rate (Kmol/day)',
#  'E06 : p 11 c 0 rate (Kmol/day)',
#  'E06 : p 12 c 1 rate (Kmol/day)',
#  'P11 : p 12 c 0 rate (Kmol/day)',
#  'E06 : p 12 reservoir P (bar)',
#  'E06 : p 13 c 0 rate (Kmol/day)',
#  ...]

# %%
# take the closest injection well parameters as baseline
data['E02 : water rate (m3/day)'] = data['I03 : water rate (m3/day)']
data['E03 : water rate (m3/day)'] = data['I03 : water rate (m3/day)']
data['E04 : water rate (m3/day)'] = data['I03 : water rate (m3/day)']
data['E05 : water rate (m3/day)'] = data['I03 : water rate (m3/day)']
data['E02 : energy (KJ/day)'] = data['I03 : energy (KJ/day)']
data['E03 : energy (KJ/day)'] = data['I03 : energy (KJ/day)']
data['E04 : energy (KJ/day)'] = data['I03 : energy (KJ/day)']
data['E05 : energy (KJ/day)'] = data['I03 : energy (KJ/day)']

# %%
# list the collumn names that should be removed
press_gridcells = data.filter(like='reservoir').columns.tolist()
chem_cols = data.filter(like='Kmol').columns.tolist()

wells = ['P01', 'P02', 'P03', 'P15', 'P16', 'I01', 'I02', 'I03', 'E01', 'E06']
wells_cols = []
for well in wells:
    well_cols = data.filter(like=well).columns.tolist()
    wells_cols += well_cols

# remove collumns from data
data.drop(columns=press_gridcells + chem_cols + wells_cols, inplace=True)

data.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'E02 : energy (KJ/day)',
#  'E02 : temperature (K)',
#  'E02 : water rate (m3/day)',
#  'time',
#  'E03 : water rate (m3/day)',
#  'P13 : BHP (bar)',
#  'FIPS c 0 (kmol)',
#  'E03 : energy (KJ/day)',
#  'P11 : energy (KJ/day)',
#  'E03 : temperature (K)',
#  'E05 : BHP (bar)',
#  'P13 : energy (KJ/day)',
#  'P11 : temperature (K)',
#  'P12 : steam rate (m3/day)',
#  'E02 : steam rate (m3/day)',
#  'P13 : steam rate (m3/day)',
#  'P14 : water rate (m3/day)',
#  'E02 : BHP (bar)',
#  'P13 : temperature (K)',
#  'P14 : temperature (K)',
#  'P12 : energy (KJ/day)',
#  'P11 : water rate (m3/day)',
#  'E03 : BHP (bar)',
#  'E04 : water rate (m3/day)',
#  'E04 : steam rate (m3/day)',
#  'E04 : temperature (K)',
#  'E04 : energy (KJ/day)',
#  'E04 : BHP (bar)',
#  'E05 : water rate (m3/day)',
#  'E05 : steam rate (m3/day)',
#  'E05 : temperature (K)',
#  'E05 : energy (KJ/day)',
#  'P12 : temperature (K)',
#  'P14 : steam rate (m3/day)',
#  'P11 : steam rate (m3/day)',
#  'P11 : BHP (bar)',
#  'P12 : water rate (m3/day)',
#  'P14 : energy (KJ/day)',
#  'P12 : BHP (bar)',
#  'P13 : water rate (m3/day)',
#  'E03 : steam rate (m3/day)',
#  'P14 : BHP (bar)']

# %%
# do a first plot to get an overview of our data
# define a plot
fig, ax = plt.subplots(2,2, figsize=(12,10), dpi=150, sharex=True)
# get plot axes
ax_list = fig.axes

# plot a few keywords in pairs for both wells
for i, key in enumerate(['temperature', 'BHP','energy (KJ/day)','water rate (m3/day)']):
    data.plot(x='time',
              y=data.filter(like=key).columns.tolist(),
              ax=ax_list[i],
              linestyle='-',
              style=['x', 'o'])
    ax_list[i].legend(fontsize=6)
    ax_list[i].grid(alpha=0.3)

plt.show()

# %% [markdown]
# ## Dataset preparation

# %%
# assign datetime as index
data['Datetime'] = pd.to_datetime('1/1/2000') + pd.to_timedelta(data['time'] * pd.Timedelta(('24 hours')), unit='h')
data.set_index('Datetime', inplace=True)

# set the new time interval
set_interval = '24h'

# %%
# generate the new index on which the data should correspond based on original index range
resample_index = pd.date_range(data.index[0] - pd.Timedelta(set_interval),
                               data.index[-1] + pd.Timedelta(set_interval), freq=set_interval, normalize=True,
                               closed='right')

# %%
# create a new index as the union of the old and new index and interpolate on the combined index
# then reindex the dataframe to the new index
tdata = data.reindex(data.index.union(resample_index)).interpolate('index').reindex(resample_index)

# maintain initial values of original dataset in the newly indexed one at the edges
tdata.iloc[0] = data.iloc[0]
tdata.iloc[-1] = data.iloc[-1]

# add the number of periods for further economic assessment
tdata['econ_periods'] = np.arange(len(tdata))

# %%
# compute the deltahours for economic and energy assessments
tdata['Deltahours'] = tdata.index.to_series().diff(1) / pd.Timedelta('1 hour')

# verify that we only have one delta
tdata['Deltahours'].unique()
# Out:
# array([nan, 24.])

# %%
# recompute time columns based on index
tdata['Time (yrs)'] = pd.to_timedelta(tdata.index - tdata.index[0]).total_seconds() / (365 * 24 * 60 * 60)

# reset index to time delta
tdata.set_index(pd.to_timedelta(tdata['Time (yrs)'] * pd.Timedelta(('365 days')), unit='s'), inplace=True)
tdata.drop(columns='time', inplace=True)

# %%
# do a quick plot to get an overview of our treated data
# define a plot
fig, ax = plt.subplots(2,2, figsize=(12,10), dpi=150, sharex=True)
# get plot axes
ax_list = fig.axes

# plot a few keywords in pairs for both wells
for i, key in enumerate(['temperature', 'BHP','energy (KJ/day)','water rate (m3/day)']):
    tdata.plot(x='Time (yrs)',
              y=data.filter(like=key).columns.tolist(),
              ax=ax_list[i],
              linestyle='-',
              style=['x', 'o'])
    ax_list[i].legend(fontsize=6)
    ax_list[i].grid(alpha=0.3)

# %% [markdown]
# ## Produced energy calculation

# %%
# check if the net volume of the produced and injected fluid equal
water_rate = [col for col in tdata.columns if 'water rate' in col]
tdata[water_rate].median().sort_values()
# Out:
# P12 : water rate (m3/day)   -8400.0
# P11 : water rate (m3/day)   -8400.0
# P14 : water rate (m3/day)   -8400.0
# P13 : water rate (m3/day)   -8400.0
# E02 : water rate (m3/day)    8400.0
# E03 : water rate (m3/day)    8400.0
# E04 : water rate (m3/day)    8400.0
# E05 : water rate (m3/day)    8400.0
# dtype: float64

# %%
kJ_day_MW = 1/3.6e6/24

# compute system power
tdata['System power (MW)'] = (abs(tdata['P11 : energy (KJ/day)']) -
                              abs(tdata['E04 : energy (KJ/day)']) +
                              abs(tdata['P12 : energy (KJ/day)']) - 
                              abs(tdata['E02 : energy (KJ/day)']) +
                              abs(tdata['P13 : energy (KJ/day)']) -
                              abs(tdata['E05 : energy (KJ/day)']) +
                              abs(tdata['P14 : energy (KJ/day)']) -
                              abs(tdata['E03 : energy (KJ/day)'])) * kJ_day_MW

# compute produced energy
tdata['Produced Energy (MWh)'] = tdata['System power (MW)'] * tdata['Deltahours']

tdata.plot('Time (yrs)', 'System power (MW)', lw=4)
pd.Series({-0.5: 80, 20.5: 80}).plot.line(linestyle='--', color='r')
# Out:
# <AxesSubplot:xlabel='Time (yrs)'>

# %% [markdown]
# ![pwd/fig_ploop.PNG](attachment:fig_ploop.PNG)

# %%
# compute the pressured drop
tdata['Pump dp (MPa)_1'] = abs(tdata['P11 : BHP (bar)'] * 0.1) - abs(tdata['E04 : BHP (bar)'] * 0.1)
tdata['Pump dp (MPa)_2'] = abs(tdata['P12 : BHP (bar)'] * 0.1) - abs(tdata['E02 : BHP (bar)'] * 0.1)
tdata['Pump dp (MPa)_3'] = abs(tdata['P13 : BHP (bar)'] * 0.1) - abs(tdata['E05 : BHP (bar)'] * 0.1)
tdata['Pump dp (MPa)_4'] = abs(tdata['P14 : BHP (bar)'] * 0.1) - abs(tdata['E03 : BHP (bar)'] * 0.1)

# %% [markdown]
# ![pwd/fig_ppower.PNG](attachment:fig_ppower.PNG)

# %%
m3_day_m3_sec = 1 / (24 * 60 * 60)
pump_efficiency = 0.5

# compute the pumping power
tdata['Pump power (MW)'] = abs(tdata['E02 : water rate (m3/day)']) * m3_day_m3_sec * \
                           (tdata['Pump dp (MPa)_1'] + tdata['Pump dp (MPa)_2'] +
                            tdata['Pump dp (MPa)_3'] + tdata['Pump dp (MPa)_4']) / pump_efficiency

# compute the pumping costs
electricity_price = 100 # euro/MWh
tdata['OpEx_pump (\u20ac)'] = tdata['Pump power (MW)'] * tdata['Deltahours'] * electricity_price

# %%
# assign the CapEx for drilling the wells
tdata['CapEx (\u20ac)'] = 0
tdata.loc[tdata.index == tdata.index[0], 'CapEx (\u20ac)'] = 65974424
periodic_OpEx_rate = 0.07
# calculate variable OpEx costs
tdata['OpEx (\u20ac)'] = tdata['CapEx (\u20ac)'].cumsum() * periodic_OpEx_rate

# %% [markdown]
# ![pwd/fig_LCOH.PNG](attachment:fig_LCOH.PNG)

# %%
# calculate LCOH
periodic_discount_rate = 0.07

# compute the LCOH costs
tdata['LCOH costs'] = tdata['CapEx (\u20ac)'].fillna(0) \
                        + tdata['OpEx (\u20ac)'] \
                          + tdata['OpEx_pump (\u20ac)'].fillna(0)

# discount LCOH costs
tdata['discounted LCOH costs'] = (tdata['LCOH costs'] /
                                      (1 + periodic_discount_rate) ** tdata['econ_periods']).cumsum()

tdata['discounted LCOH energy'] = (tdata['Produced Energy (MWh)'] /
                                        (1 + periodic_discount_rate) ** tdata[
                                            'econ_periods']).cumsum()

tdata[r'LCOH (€/MWh)'] = tdata['discounted LCOH costs'] / tdata['discounted LCOH energy']

# %%
# do our final plot with the overview
# define a plot
fig, ax = plt.subplots(2,3, figsize=(12,8), dpi=150, sharex=True)
# get plot axes
ax_list = fig.axes

# plot a few keywords in pairs for both wells
for i, key in enumerate(['temperature', 'BHP','water rate (m3/day)',
                         'power', 'Ex','LCOH (€/MWh)']):
    tdata.plot(x='Time (yrs)',
              y=tdata.filter(like=key).columns.tolist(),
              ax=ax_list[i],
              linestyle='-',
              style=['x', 'o'])
    ax_list[i].legend(fontsize=6)
    ax_list[i].grid(alpha=0.3)
    if key == 'LCOH (€/MWh)':
        ax_list[i].annotate('%0.2f @ time: %.2f yrs' % (tdata[key].iloc[-1], tdata['Time (yrs)'].iloc[-1]),
                            xy=(0.5, 0.5), va='center', ha='center',
                            xycoords=('axes fraction'))

# %%
def drillingcostnl(depth):
    """
    Calculate the cost of drilling as a function of depth
    Reference source:
        https://www.thermogis.nl/en/economic-model

    :param depth: float
        measured depth along hole in meters

    :return: float
        costs in euros
    """
    drilling_cost_nl = 375000 + 1150 * depth + 0.3 * depth ** 2
    return(drilling_cost_nl)

# %%
depth = np.arange(500, 3500, 1)

costs = drillingcostnl(depth)

fig, ax = plt.subplots(figsize=(6,5))
ax.plot(costs, depth, label='ThermoGIS drilling cost')
ax.set_xlabel('Cost (€)')
ax.set_ylabel('Depth (m)')
ax.grid(alpha=0.3)
ax.legend()
ax.invert_yaxis()

# %% [markdown]
# ![pwd/fig_costs.PNG](attachment:fig_costs.PNG)
